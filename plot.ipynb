# %% [markdown]
# # Diffusion-TS Tutorial
#
# ## Diffusion-TS: Interpretable Diffusion for General Time Series Generation
#
# This notebook describes the user-guide of a time-series synthetic data generation application using Diffusion-TS framework.

# %% [markdown]
# ## Necessary packages and functions call

# %%
import torch
import random
import numpy as np

from Utils.metric_utils import visualization

# %% [markdown]
# ## Sampling

# %%
ori_data = np.load('')
fake_data = np.load('')
print(fake_data.shape)
# Out:
# (17357, 64, 7)

# %% [markdown]
# ## Visualization
#
# We visualize the original and synthetic data distributions using PCA, tSNE and Density analysis.

# %%
visualization(ori_data=ori_data, generated_data=fake_data, analysis='pca', compare=3000)
# visualization(ori_data=ori_data, generated_data=fake_data, analysis='tsne', compare=3000)
# visualization(ori_data=ori_data, generated_data=fake_data, analysis='kernel', compare=3000)
